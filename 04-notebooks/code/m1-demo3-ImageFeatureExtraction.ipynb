# %% [markdown]
# # Extracting Features from Images
# ##### Obtaining pixel intensities for image and transforming those into usable features

# %% [markdown]
# #### Installation of opencv may be required
#
# OpenCV == Open Source Computer Vision Library

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in C:\Users\Pc\AppData\Roaming\Python\Python313\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in C:\Users\Pc\AppData\Roaming\Python\Python313\site-packages (from opencv-python) (2.4.3)

# %%
import cv2

# %% [markdown]
# #### Load an image from which to extract RGB pixel intensities

# %%
# Image with dimensions 173x130
imagePath = '../data/dog.jpg'

image = cv2.imread(imagePath)

# %% [markdown]
# **NOTA:** *OpenCV lee las imágenes en formato BGR (Azul, Verde, Rojo), pero matplotlib las muestra en formato RGB (Rojo, Verde, Azul). Esto invierte los canales de color, dándole ese tono azulado/extraño a la imagen.*

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# #### View image using matplotlib

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %% [markdown]
# #### Image array contains RGB values for each pixel in the image

# %%
image.shape
# Out:
# (130, 173, 3)

# %%
image
# Out:
# array([[[164, 171, 199],
#         [198, 206, 227],
#         [231, 237, 249],
#         ...,
#         [234, 242, 253],
#         [235, 243, 254],
#         [235, 243, 254]],
#
#        [[188, 195, 221],
#         [201, 209, 228],
#         [228, 237, 246],
#         ...,
#         [235, 243, 254],
#         [237, 243, 255],
#         [236, 242, 254]],
#
#        [[198, 209, 227],
#         [201, 210, 225],
#         [222, 231, 238],
#         ...,
#         [236, 242, 254],
#         [238, 242, 254],
#         [237, 241, 253]],
#
#        ...,
#
#        [[208, 207, 203],
#         [204, 203, 199],
#         [203, 202, 200],
#         ...,
#         [118, 112,  98],
#         [119, 113,  99],
#         [118, 112,  98]],
#
#        [[206, 202, 201],
#         [208, 204, 203],
#         [209, 205, 204],
#         ...,
#         [119, 115, 103],
#         [123, 119, 107],
#         [120, 116, 104]],
#
#        [[205, 201, 200],
#         [206, 202, 201],
#         [208, 204, 203],
#         ...,
#         [122, 118, 106],
#         [127, 123, 111],
#         [124, 120, 108]]], dtype=uint8)

# %% [markdown]
# #### Each pixel has RGB intensities

# %%
image[0][0]
# Out:
# array([164, 171, 199], dtype=uint8)

# %% [markdown]
# #### Scale this image to a smaller size

# %%
size=(32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[228, 237, 244],
#         [253, 254, 251],
#         [242, 250, 255],
#         ...,
#         [242, 247, 253],
#         [238, 245, 255],
#         [236, 243, 254]],
#
#        [[108, 118, 126],
#         [211, 218, 237],
#         [144, 156, 166],
#         ...,
#         [242, 246, 255],
#         [241, 245, 255],
#         [233, 241, 254]],
#
#        [[251, 253, 254],
#         [252, 254, 255],
#         [251, 253, 254],
#         ...,
#         [230, 239, 250],
#         [214, 224, 243],
#         [165, 177, 190]],
#
#        ...,
#
#        [[210, 206, 206],
#         [213, 209, 208],
#         [212, 208, 207],
#         ...,
#         [138, 131, 119],
#         [141, 135, 121],
#         [136, 129, 115]],
#
#        [[211, 208, 207],
#         [212, 209, 211],
#         [214, 211, 213],
#         ...,
#         [130, 124, 110],
#         [124, 118, 104],
#         [127, 121, 107]],
#
#        [[206, 204, 202],
#         [213, 210, 211],
#         [211, 209, 211],
#         ...,
#         [137, 132, 119],
#         [118, 113, 100],
#         [118, 112,  99]]], dtype=uint8)

# %% [markdown]
# #### Image array can be flattened into a one-dimensional array

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE )
image_grayscale = cv2.cvtColor(image_grayscale, cv2.COLOR_BGR2RGB) # Lo transformamos de GBR a RGB

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (130, 173, 3)

# %%
image_grayscale
# Out:
# array([[[172, 172, 172],
#         [206, 206, 206],
#         [237, 237, 237],
#         ...,
#         [241, 241, 241],
#         [242, 242, 242],
#         [242, 242, 242]],
#
#        [[196, 196, 196],
#         [209, 209, 209],
#         [235, 235, 235],
#         ...,
#         [242, 242, 242],
#         [243, 243, 243],
#         [242, 242, 242]],
#
#        [[208, 208, 208],
#         [209, 209, 209],
#         [229, 229, 229],
#         ...,
#         [242, 242, 242],
#         [242, 242, 242],
#         [241, 241, 241]],
#
#        ...,
#
#        [[207, 207, 207],
#         [203, 203, 203],
#         [202, 202, 202],
#         ...,
#         [112, 112, 112],
#         [113, 113, 113],
#         [112, 112, 112]],
#
#        [[203, 203, 203],
#         [205, 205, 205],
#         [206, 206, 206],
#         ...,
#         [115, 115, 115],
#         [119, 119, 119],
#         [116, 116, 116]],
#
#        [[202, 202, 202],
#         [203, 203, 203],
#         [205, 205, 205],
#         ...,
#         [118, 118, 118],
#         [123, 123, 123],
#         [120, 120, 120]]], dtype=uint8)

# %%
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (130, 173, 1, 3)

# %%
expanded_image_grayscale
# Out:
# array([[[[172, 172, 172]],
#
#         [[206, 206, 206]],
#
#         [[237, 237, 237]],
#
#         ...,
#
#         [[241, 241, 241]],
#
#         [[242, 242, 242]],
#
#         [[242, 242, 242]]],
#
#
#        [[[196, 196, 196]],
#
#         [[209, 209, 209]],
#
#         [[235, 235, 235]],
#
#         ...,
#
#         [[242, 242, 242]],
#
#         [[243, 243, 243]],
#
#         [[242, 242, 242]]],
#
#
#        [[[208, 208, 208]],
#
#         [[209, 209, 209]],
#
#         [[229, 229, 229]],
#
#         ...,
#
#         [[242, 242, 242]],
#
#         [[242, 242, 242]],
#
#         [[241, 241, 241]]],
#
#
#        ...,
#
#
#        [[[207, 207, 207]],
#
#         [[203, 203, 203]],
#
#         [[202, 202, 202]],
#
#         ...,
#
#         [[112, 112, 112]],
#
#         [[113, 113, 113]],
#
#         [[112, 112, 112]]],
#
#
#        [[[203, 203, 203]],
#
#         [[205, 205, 205]],
#
#         [[206, 206, 206]],
#
#         ...,
#
#         [[115, 115, 115]],
#
#         [[119, 119, 119]],
#
#         [[116, 116, 116]]],
#
#
#        [[[202, 202, 202]],
#
#         [[203, 203, 203]],
#
#         [[205, 205, 205]],
#
#         ...,
#
#         [[118, 118, 118]],
#
#         [[123, 123, 123]],
#
#         [[120, 120, 120]]]], dtype=uint8)
